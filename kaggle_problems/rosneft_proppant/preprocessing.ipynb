# %%
import os
import sys
while not os.getcwd().endswith('ml'):
    os.chdir('..')
sys.path.insert(0, os.getcwd())

# %%
import math
import copy
import cv2
import numpy as np
import random
from shutil import copyfile
from pathlib import Path
from matplotlib import pyplot as plt
from kaggle_problems.rosneft_proppant import helpers
from kaggle_problems.rosneft_proppant.helpers import *
helpers.circleContour = ColoredCircleContour()

# %%
DATA_DIR = "kaggle_problems/rosneft_proppant/data"
ORIGINAL_IMG_DIR = "kaggle_problems/rosneft_proppant/data/train"
DEBUG_IMG_DIR = "kaggle_problems/rosneft_proppant/data/debug"
PROCESSING_IMG_DIR = "kaggle_problems/rosneft_proppant/data/processing"

INNER_SHAPE = (143.5, 86.5)
OUTER_SHAPE = (147.5, 90.5)
TARGET_SHAPE = (round(INNER_SHAPE[0] * 30), round(INNER_SHAPE[1] * 30))

# %%
def increase_brightness(img, value):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %%
def check_size_contour(img, contour, down, up):
    area = cv2.contourArea(contour)
    return area > 1000 and \
        area / (img.shape[0] * img.shape[1]) >= down  and \
        area / (img.shape[0] * img.shape[1]) <= up

def is_rectange_area(contour):
    epsilon = 0.01 * cv2.arcLength(contour,True)
    res = cv2.approxPolyDP(contour,epsilon,True)
    return len(res) == 4 

def is_contours_simular(a, b, eps=0.1):
    return (abs(cv2.contourArea(a) - cv2.contourArea(b)) / (cv2.contourArea(a) + cv2.contourArea(b)) < eps) and \
        (abs(cv2.arcLength(a, True) - cv2.arcLength(b, True)) / (cv2.arcLength(a, True) + cv2.arcLength(b, True)) < eps)

# %%
def get_main_contour(thresh, find_inner):
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)
    hierarchy = hierarchy[0]
    origin_contours = copy.deepcopy(contours)
    contours = [(contour, i) for contour, i in zip(contours, range(len(contours)))]

    
    # filters
    contours = [(contour, i) for (contour, i) in contours if check_size_contour(img, contour, 0.1, 0.5)]
    contours = [(contour, i) for (contour, i) in contours if is_rectange_area(contour)]
    
    if (find_inner):
        set_of_contours = set([i for c, i in contours])
        contours = [(contour, i) for (contour, i) in contours if hierarchy[i][-1] in set_of_contours] # stay only if parent is rectangle
        contours = [(contour, i) for (contour, i) in contours if is_contours_simular(contour, origin_contours[hierarchy[i][-1]])]
    
    if (len(contours) != 1):
        return None

    return contours[0][0]

# %%
def order_rectangle(rectangle):
    return rectangle

def squeeze(rectangle):
    pass

def outer2inner(contour, img):
    epsilon = 0.01 * cv2.arcLength(contour, True)
    res = cv2.approxPolyDP(contour, epsilon, True)
    return contour

# %%
all_img = [img for img in os.listdir(ORIGINAL_IMG_DIR) if img.endswith('.jpg') ]

for img_name in all_img:
    print(img_name)
    img_number, _ = img_name.split('.')
    debug_dir = "{}/{}".format(DEBUG_IMG_DIR, img_number)
    Path(debug_dir).mkdir(exist_ok=True, parents=True)
    
    img = cv2.imread("{}/{}".format(ORIGINAL_IMG_DIR, img_name)) 
    origin_img = copy.deepcopy(img)
    img = increase_brightness(img, 100)    
    gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
    
    cv2.imwrite("{}/thresh.jpg".format(debug_dir), thresh)
    cv2.imwrite("{}/img_with_brightness.jpg".format(debug_dir), img)
    
    is_inner = True
    contour = get_main_contour(thresh, find_inner=is_inner)
    if contour is None:
        is_inner = False
        contour = get_main_contour(thresh, find_inner=is_inner)
        print("find outer contour for img_name: {}", img_name)
        
    if contour is None:
        print("ERROR: {}", img_name)
        continue
        
    # draw
    img_with_main_contour = img
    epsilon = 0.01 * cv2.arcLength(contour,True)
    res = cv2.approxPolyDP(contour,epsilon,True)
    cv2.drawContours(img, [res], -1, get_random_color(), 10)
    cv2.imwrite("{}/img_with_main_contour.jpg".format(debug_dir), img_with_main_contour)
    
    # трансформация
    res = np.float32([[i[0][0], i[0][1]] for i in res])
    res = order_rectangle(res)
    
    l = round(dist(res[0], res[1]))
    h = round(dist(res[1], res[2]))
   
    needed_contour = np.float32([[0, 0], [0, l], [h, l], [h, 0]])
   
    M = cv2.getPerspectiveTransform(res,needed_contour)
    dst = cv2.warpPerspective(origin_img, M, (h, l))
    
    if dst.shape[0] < dst.shape[1]:
        dst = cv2.rotate(dst, cv2.ROTATE_90_CLOCKWISE)
        
    assert(dst.shape[0] >= dst.shape[1])
        
    if not is_inner:
        x_diff = round((OUTER_SHAPE[0] - INNER_SHAPE[0]) / OUTER_SHAPE[0] * dst.shape[0] / 2)
        y_diff = round((OUTER_SHAPE[1] - INNER_SHAPE[1]) / OUTER_SHAPE[1] * dst.shape[1] / 2)
        
        dst = dst[x_diff:-x_diff, y_diff:-y_diff]
    
    # изменение пропорций картинки
    dst = cv2.resize(dst, (TARGET_SHAPE[1], TARGET_SHAPE[0]))
    
        
    main_area_dir = "{}/main_area".format(PROCESSING_IMG_DIR)
    Path(main_area_dir).mkdir(exist_ok=True, parents=True)
    
    cv2.imwrite("{}/{}".format(main_area_dir, img_name), dst)
# Out:
# 63.jpg
# 189.jpg
# 77.jpg
# 638.jpg
# 604.jpg
# 162.jpg
# 176.jpg
# 88.jpg
# 610.jpg
# 348.jpg
# 360.jpg
# 406.jpg
# 412.jpg
# 374.jpg
# 599.jpg
# 228.jpg
# 214.jpg
# 572.jpg
# 566.jpg
# 200.jpg
# 758.jpg
# 770.jpg
# 764.jpg
# 765.jpg
# 771.jpg
# 759.jpg
# 567.jpg
# 201.jpg
# 215.jpg
# 573.jpg
# 229.jpg
# 598.jpg
# 413.jpg
# 375.jpg
# 361.jpg
# 407.jpg
# 349.jpg
# find outer contour for img_name: {} 349.jpg
# 177.jpg
# 611.jpg
# 89.jpg
# 605.jpg
# 163.jpg
# 639.jpg
# 188.jpg
# 76.jpg
# find outer contour for img_name: {} 76.jpg
# 62.jpg
# 74.jpg
# 60.jpg
# 48.jpg
# 149.jpg
# 613.jpg
# 175.jpg
# 161.jpg
# 607.jpg
# 388.jpg
# 439.jpg
# 377.jpg
# 411.jpg
# 405.jpg
# 363.jpg
# 559.jpg
# 203.jpg
# 565.jpg
# 571.jpg
# 217.jpg
# 767.jpg
# 773.jpg
# 772.jpg
# 766.jpg
# 570.jpg
# 216.jpg
# 202.jpg
# 564.jpg
# 558.jpg
# 404.jpg
# 362.jpg
# 376.jpg
# 410.jpg
# 438.jpg
# 389.jpg
# 160.jpg
# 606.jpg
# 612.jpg
# 174.jpg
# 148.jpg
# 49.jpg
# 61.jpg
# 75.jpg
# 59.jpg
# 71.jpg
# 65.jpg
# 170.jpg
# 616.jpg
# 602.jpg
# 164.jpg
# 158.jpg
# 399.jpg
# 414.jpg
# 372.jpg
# 366.jpg
# 400.jpg
# 428.jpg
# 560.jpg
# 206.jpg
# 212.jpg
# 574.jpg
# 548.jpg
# 789.jpg
# 762.jpg
# 776.jpg
# 777.jpg
# 763.jpg
# 788.jpg
# 549.jpg
# 213.jpg
# find outer contour for img_name: {} 213.jpg
# 575.jpg
# 561.jpg
# 207.jpg
# 429.jpg
# 367.jpg
# 401.jpg
# 415.jpg
# 373.jpg
# 398.jpg
# find outer contour for img_name: {} 398.jpg
# 159.jpg
# 603.jpg
# 165.jpg
# 171.jpg
# 617.jpg
# 64.jpg
# 70.jpg
# 58.jpg
# 8.jpg
# 198.jpg
# 66.jpg
# 72.jpg
# 167.jpg
# 601.jpg
# 99.jpg
# 615.jpg
# 173.jpg
# 629.jpg
# 403.jpg
# 365.jpg
# 371.jpg
# 417.jpg
# 359.jpg
# 588.jpg
# 577.jpg
# 211.jpg
# 205.jpg
# 563.jpg
# 239.jpg
# 775.jpg
# 761.jpg
# 749.jpg
# 748.jpg
# 760.jpg
# 774.jpg
# 238.jpg
# 204.jpg
# 562.jpg
# 576.jpg
# 210.jpg
# 589.jpg
# 358.jpg
# 370.jpg
# 416.jpg
# 402.jpg
# 364.jpg
# 628.jpg
# 614.jpg
# 172.jpg
# 166.jpg
# 98.jpg
# 600.jpg
# 73.jpg
# 199.jpg
# 67.jpg
# 9.jpg
# 698.jpg
# 14.jpg
# 28.jpg
# 129.jpg
# 101.jpg
# 667.jpg
# find outer contour for img_name: {} 667.jpg
# 673.jpg
# 115.jpg
# 459.jpg
# 465.jpg
# 303.jpg
# 317.jpg
# 471.jpg
# 288.jpg
# 539.jpg
# 511.jpg
# 277.jpg
# 263.jpg
# 505.jpg
# 713.jpg
# 707.jpg
# 706.jpg
# 712.jpg
# 262.jpg
# 504.jpg
# 510.jpg
# find outer contour for img_name: {} 510.jpg
# 276.jpg
# 538.jpg
# 289.jpg
# 316.jpg
# 470.jpg
# 464.jpg
# 302.jpg
# 458.jpg
# 672.jpg
# 114.jpg
# 100.jpg
# 666.jpg
# 128.jpg
# 29.jpg
# 15.jpg
# 699.jpg
# 17.jpg
# 658.jpg
# 116.jpg
# 670.jpg
# 664.jpg
# 102.jpg
# 499.jpg
# 328.jpg
# 472.jpg
# 314.jpg
# 300.jpg
# 466.jpg
# 248.jpg
# 506.jpg
# 260.jpg
# 274.jpg
# 512.jpg
# 738.jpg
# 704.jpg
# 710.jpg
# 711.jpg
# 705.jpg
# 739.jpg
# 275.jpg
# 513.jpg
# 507.jpg
# 261.jpg
# 249.jpg
# 301.jpg
# 467.jpg
# 473.jpg
# 315.jpg
# find outer contour for img_name: {} 315.jpg
# 329.jpg
# 498.jpg
# 665.jpg
# 103.jpg
# 117.jpg
# 671.jpg
# 659.jpg
# 16.jpg
# 12.jpg
# 675.jpg
# 113.jpg
# 107.jpg
# 661.jpg
# 649.jpg
# 488.jpg
# 311.jpg
# 477.jpg
# 463.jpg
# 305.jpg
# 339.jpg
# 265.jpg
# 503.jpg
# 517.jpg
# 271.jpg
# 259.jpg
# 701.jpg
# 715.jpg
# 729.jpg
# 728.jpg
# 714.jpg
# 700.jpg
# 258.jpg
# 516.jpg
# 270.jpg
# 264.jpg
# 502.jpg
# 338.jpg
# 462.jpg
# 304.jpg
# 310.jpg
# 476.jpg
# 489.jpg
# 648.jpg
# 106.jpg
# 660.jpg
# 674.jpg
# 112.jpg
# 13.jpg
# 39.jpg
# 689.jpg
# 11.jpg
# find outer contour for img_name: {} 11.jpg
# 662.jpg
# 104.jpg
# 110.jpg
# 676.jpg
# 138.jpg
# 306.jpg
# 460.jpg
# 474.jpg
# 312.jpg
# 448.jpg
# 299.jpg
# 272.jpg
# 514.jpg
# 500.jpg
# find outer contour for img_name: {} 500.jpg
# 266.jpg
# 528.jpg
# 716.jpg
# 702.jpg
# 703.jpg
# 717.jpg
# 529.jpg
# 501.jpg
# 267.jpg
# 273.jpg
# 515.jpg
# 298.jpg
# 449.jpg
# 475.jpg
# 313.jpg
# 307.jpg
# 461.jpg
# 139.jpg
# 111.jpg
# 677.jpg
# 663.jpg
# 105.jpg
# 10.jpg
# 688.jpg
# 38.jpg
# 21.jpg
# 35.jpg
# find outer contour for img_name: {} 35.jpg
# ERROR: {} 35.jpg
# 685.jpg
# 691.jpg
# 108.jpg
# 120.jpg
# 646.jpg
# 652.jpg
# 134.jpg
# 487.jpg
# 493.jpg
# 478.jpg
# 444.jpg
# 322.jpg
# 336.jpg
# 450.jpg
# 295.jpg
# 281.jpg
# 518.jpg
# 530.jpg
# 256.jpg
# 242.jpg
# 524.jpg
# 732.jpg
# 726.jpg
# 727.jpg
# 733.jpg
# 243.jpg
# 525.jpg
# 531.jpg
# 257.jpg
# 519.jpg
# 280.jpg
# 294.jpg
# 337.jpg
# 451.jpg
# 445.jpg
# 323.jpg
# 479.jpg
# 492.jpg
# 486.jpg
# 653.jpg
# 135.jpg
# 121.jpg
# 647.jpg
# 109.jpg
# 690.jpg
# 684.jpg
# 34.jpg
# 20.jpg
# 36.jpg
# 22.jpg
# 692.jpg
# 686.jpg
# 679.jpg
# 137.jpg
# 651.jpg
# 645.jpg
# 123.jpg
# 490.jpg
# 484.jpg
# 309.jpg
# 453.jpg
# 335.jpg
# 321.jpg
# 447.jpg
# 282.jpg
# 296.jpg
# 269.jpg
# 527.jpg
# 241.jpg
# 255.jpg
# 533.jpg
# 719.jpg
# 725.jpg
# 731.jpg
# 730.jpg
# 724.jpg
# 718.jpg
# 254.jpg
# 532.jpg
# 526.jpg
# 240.jpg
# 268.jpg
# 297.jpg
# 283.jpg
# 320.jpg
# 446.jpg
# 452.jpg
# 334.jpg
# 308.jpg
# 485.jpg
# 491.jpg
# 644.jpg
# 122.jpg
# 136.jpg
# 650.jpg
# 678.jpg
# 687.jpg
# 693.jpg
# 23.jpg
# 37.jpg
# 697.jpg
# 683.jpg
# 33.jpg
# 27.jpg
# 654.jpg
# 132.jpg
# 126.jpg
# 640.jpg
# 668.jpg
# 495.jpg
# 481.jpg
# 330.jpg
# 456.jpg
# 442.jpg
# 324.jpg
# find outer contour for img_name: {} 324.jpg
# 318.jpg
# 287.jpg
# 293.jpg
# 244.jpg
# 522.jpg
# 536.jpg
# 250.jpg
# 278.jpg
# 720.jpg
# 734.jpg
# 708.jpg
# 709.jpg
# 735.jpg
# 721.jpg
# 279.jpg
# 537.jpg
# 251.jpg
# 245.jpg
# 523.jpg
# 292.jpg
# 286.jpg
# 319.jpg
# 443.jpg
# 325.jpg
# 331.jpg
# 457.jpg
# 480.jpg
# 494.jpg
# 669.jpg
# 127.jpg
# 641.jpg
# 655.jpg
# 133.jpg
# 26.jpg
# 32.jpg
# 682.jpg
# 696.jpg
# 680.jpg
# 18.jpg
# 694.jpg
# 24.jpg
# 30.jpg
# 643.jpg
# 125.jpg
# 131.jpg
# 657.jpg
# 119.jpg
# 482.jpg
# 496.jpg
# 327.jpg
# 441.jpg
# 455.jpg
# 333.jpg
# 469.jpg
# 290.jpg
# 284.jpg
# 253.jpg
# 535.jpg
# 521.jpg
# 247.jpg
# 509.jpg
# 737.jpg
# 723.jpg
# 722.jpg
# 736.jpg
# 508.jpg
# 520.jpg
# 246.jpg
# 252.jpg
# 534.jpg
# 285.jpg
# 291.jpg
# 468.jpg
# 454.jpg
# 332.jpg
# 326.jpg
# 440.jpg
# 497.jpg
# 483.jpg
# 118.jpg
# 130.jpg
# 656.jpg
# 642.jpg
# 124.jpg
# 31.jpg
# 25.jpg
# 695.jpg
# 19.jpg
# 681.jpg
# 42.jpg
# 4.jpg
# 56.jpg
# 180.jpg
# 194.jpg
# 81.jpg
# 619.jpg
# 95.jpg
# 625.jpg
# 143.jpg
# 157.jpg
# 631.jpg
# 382.jpg
# 396.jpg
# 369.jpg
# 341.jpg
# 427.jpg
# 433.jpg
# 355.jpg
# 590.jpg
# find outer contour for img_name: {} 590.jpg
# 584.jpg
# 209.jpg
# 235.jpg
# 553.jpg
# 547.jpg
# 221.jpg
# 786.jpg
# 779.jpg
# 751.jpg
# 745.jpg
# 744.jpg
# 750.jpg
# 778.jpg
# 787.jpg
# 546.jpg
# 220.jpg
# 234.jpg
# 552.jpg
# 208.jpg
# 585.jpg
# 591.jpg
# 432.jpg
# 354.jpg
# 340.jpg
# 426.jpg
# 368.jpg
# 397.jpg
# 383.jpg
# 156.jpg
# 630.jpg
# 624.jpg
# 142.jpg
# 94.jpg
# 618.jpg
# 80.jpg
# 195.jpg
# 181.jpg
# 5.jpg
# 57.jpg
# 43.jpg
# 55.jpg
# 7.jpg
# 41.jpg
# 69.jpg
# 197.jpg
# 183.jpg
# 96.jpg
# find outer contour for img_name: {} 96.jpg
# 168.jpg
# 82.jpg
# 632.jpg
# 154.jpg
# 140.jpg
# 626.jpg
# 395.jpg
# 381.jpg
# 418.jpg
# 356.jpg
# 430.jpg
# find outer contour for img_name: {} 430.jpg
# 424.jpg
# 342.jpg
# 587.jpg
# 593.jpg
# 578.jpg
# 222.jpg
# 544.jpg
# 550.jpg
# 236.jpg
# 785.jpg
# 746.jpg
# 752.jpg
# 753.jpg
# find outer contour for img_name: {} 753.jpg
# 747.jpg
# 790.jpg
# 784.jpg
# 551.jpg
# 237.jpg
# 223.jpg
# 545.jpg
# 579.jpg
# 592.jpg
# 586.jpg
# 425.jpg
# 343.jpg
# 357.jpg
# 431.jpg
# 419.jpg
# 380.jpg
# 394.jpg
# 141.jpg
# 627.jpg
# 633.jpg
# 155.jpg
# 83.jpg
# 97.jpg
# 169.jpg
# 182.jpg
# 68.jpg
# 196.jpg
# 40.jpg
# 54.jpg
# 6.jpg
# 192.jpg
# 78.jpg
# 186.jpg
# 2.jpg
# 50.jpg
# 44.jpg
# 151.jpg
# 637.jpg
# 623.jpg
# 145.jpg
# 93.jpg
# 87.jpg
# 179.jpg
# 390.jpg
# 384.jpg
# 435.jpg
# 353.jpg
# 347.jpg
# find outer contour for img_name: {} 347.jpg
# 421.jpg
# 409.jpg
# 582.jpg
# 596.jpg
# 541.jpg
# 227.jpg
# 233.jpg
# 555.jpg
# 569.jpg
# 780.jpg
# 743.jpg
# 757.jpg
# 756.jpg
# 742.jpg
# 781.jpg
# 568.jpg
# 232.jpg
# find outer contour for img_name: {} 232.jpg
# 554.jpg
# 540.jpg
# 226.jpg
# 597.jpg
# 583.jpg
# 408.jpg
# 346.jpg
# 420.jpg
# 434.jpg
# 352.jpg
# 385.jpg
# 391.jpg
# 86.jpg
# 178.jpg
# 92.jpg
# 622.jpg
# 144.jpg
# 150.jpg
# 636.jpg
# 45.jpg
# find outer contour for img_name: {} 45.jpg
# 3.jpg
# 51.jpg
# 79.jpg
# 187.jpg
# 193.jpg
# 185.jpg
# 191.jpg
# 47.jpg
# 53.jpg
# 1.jpg
# 146.jpg
# 620.jpg
# 634.jpg
# 152.jpg
# 84.jpg
# 608.jpg
# 90.jpg
# 387.jpg
# 393.jpg
# 422.jpg
# 344.jpg
# 350.jpg
# 436.jpg
# 378.jpg
# 595.jpg
# 581.jpg
# 556.jpg
# find outer contour for img_name: {} 556.jpg
# 230.jpg
# 224.jpg
# 542.jpg
# 218.jpg
# 783.jpg
# 754.jpg
# 740.jpg
# 768.jpg
# 769.jpg
# 741.jpg
# 755.jpg
# 782.jpg
# 219.jpg
# 225.jpg
# 543.jpg
# 557.jpg
# 231.jpg
# 580.jpg
# 594.jpg
# 379.jpg
# 351.jpg
# 437.jpg
# 423.jpg
# 345.jpg
# 392.jpg
# 386.jpg
# 91.jpg
# 609.jpg
# 85.jpg
# 635.jpg
# 153.jpg
# 147.jpg
# 621.jpg
# 52.jpg
# 46.jpg
# 190.jpg
# 184.jpg

# %%
all_img = [img for img in os.listdir(PROCESSING_IMG_DIR + "/main_area") if img.endswith('.jpg') ]

shapes = []
for img_name in all_img:
    img_number, _ = img_name.split('.')
    img = cv2.imread("{}/{}".format(PROCESSING_IMG_DIR + "/main_area", img_name))
    shapes.append(img.shape)

# %%
v = [min(i[1], i[0]) / max(i[0], i[1]) for i in shapes]
mi = [min(i[1], i[0]) for i in shapes]
ma = [max(i[1], i[0]) for i in shapes]

# %%
plt.hist(v, bins=100)
plt.show()
plt.hist(mi, bins=100)
plt.show()
plt.hist(ma, bins=100)
plt.show()
